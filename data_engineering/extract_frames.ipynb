# %%
import cv2
import os

# %%
# Extract frames (2ps) from video and save them as images in frame_directory
# FILEPATH: /Volumes/TOSHIBA EXT/data/scripts/extract_frames.ipynb
# Extract frames (1 per second) from video and save them as images in frame_directory
def extract_frames_1fps(video_name, video_folder, frame_directory, desired_fps):
  video_path = os.path.join(video_folder, video_name)
  vidcap = cv2.VideoCapture(video_path)
  success, image = vidcap.read()
  count = 0
  fps = vidcap.get(cv2.CAP_PROP_FPS)  # Get the frames per second (fps) of the video
  print(fps)

  # Create directory
  output_path = os.path.join(frame_directory, video_name[:-4])
  os.makedirs(output_path)

  while success:
    if count % round(fps / desired_fps) == 0:
      image_path = os.path.join(output_path, video_name.replace('.mp4', '') + "_frame%d.jpg" % count)
      cv2.imwrite(image_path, image)  # Save frame as JPEG file
      print('Saved frame %d' % count)
    success, image = vidcap.read()
    count += 1

# %%
for video in os.listdir(video_folder):
  video_folder = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos'
  frame_directory = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/frames_1'
  if video == 'gfp_solomon1.mp4':
    extract_frames_1fps(video, video_folder, frame_directory, desired_fps)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for video in os.listdir(video_folder):
#       2   video_folder = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos'
#       3   frame_directory = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/frames_1'
#
# FileNotFoundError: [Errno 2] No such file or directory: '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/val1/videos'

# %%
VAL_SEQUENCES = [
  'val1_difficult1',
  'val1_difficult2',
  'val1_easy1',
  'val1_easy2',
  'val1_medium1',
  'val1_medium2',
  'sp_natgeo2',
  'gfp_hawaii1',
  'shlife_scalloped4',
  'gfp_fiji1',
  'shlife_smooth2',
  'gfp_niue1',
  'gfp_solomon1',
  'gfp_montserrat1',
  'gfp_rand3',
  'shlife_bull4'
]

base_dir = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/'

fpss = [0.5, 1, 2, 5]

for sequence in VAL_SEQUENCES[6:]:
  source = sequence.split('_')[0]
  for fps in fpss:
    print(f'extracting at {fps} fps')
    frame_directory = os.path.join(base_dir, source, 'frames_' + str(fps) + 'fps')
    video_folder = os.path.join(base_dir, source, 'videos')
    print(video_folder)
    extract_frames_1fps(sequence + '.mp4', video_folder, frame_directory, fps)
# Out:
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/sp/videos
# 29.97
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# Saved frame 480
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/sp/videos
# 29.97
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# Saved frame 450
# Saved frame 480
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/sp/videos
# 29.97
# Saved frame 0
# Saved frame 15
# Saved frame 30
# Saved frame 45
# Saved frame 60
# Saved frame 75
# Saved frame 90
# Saved frame 105
# Saved frame 120
# Saved frame 135
# Saved frame 150
# Saved frame 165
# Saved frame 180
# Saved frame 195
# Saved frame 210
# Saved frame 225
# Saved frame 240
# Saved frame 255
# Saved frame 270
# Saved frame 285
# Saved frame 300
# Saved frame 315
# Saved frame 330
# Saved frame 345
# Saved frame 360
# Saved frame 375
# Saved frame 390
# Saved frame 405
# Saved frame 420
# Saved frame 435
# Saved frame 450
# Saved frame 465
# Saved frame 480
# extracting at 5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/sp/videos
# 29.97
# Saved frame 0
# Saved frame 6
# Saved frame 12
# Saved frame 18
# Saved frame 24
# Saved frame 30
# Saved frame 36
# Saved frame 42
# Saved frame 48
# Saved frame 54
# Saved frame 60
# Saved frame 66
# Saved frame 72
# Saved frame 78
# Saved frame 84
# Saved frame 90
# Saved frame 96
# Saved frame 102
# Saved frame 108
# Saved frame 114
# Saved frame 120
# Saved frame 126
# Saved frame 132
# Saved frame 138
# Saved frame 144
# Saved frame 150
# Saved frame 156
# Saved frame 162
# Saved frame 168
# Saved frame 174
# Saved frame 180
# Saved frame 186
# Saved frame 192
# Saved frame 198
# Saved frame 204
# Saved frame 210
# Saved frame 216
# Saved frame 222
# Saved frame 228
# Saved frame 234
# Saved frame 240
# Saved frame 246
# Saved frame 252
# Saved frame 258
# Saved frame 264
# Saved frame 270
# Saved frame 276
# Saved frame 282
# Saved frame 288
# Saved frame 294
# Saved frame 300
# Saved frame 306
# Saved frame 312
# Saved frame 318
# Saved frame 324
# Saved frame 330
# Saved frame 336
# Saved frame 342
# Saved frame 348
# Saved frame 354
# Saved frame 360
# Saved frame 366
# Saved frame 372
# Saved frame 378
# Saved frame 384
# Saved frame 390
# Saved frame 396
# Saved frame 402
# Saved frame 408
# Saved frame 414
# Saved frame 420
# Saved frame 426
# Saved frame 432
# Saved frame 438
# Saved frame 444
# Saved frame 450
# Saved frame 456
# Saved frame 462
# Saved frame 468
# Saved frame 474
# Saved frame 480
# Saved frame 486
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# Saved frame 480
# Saved frame 540
# Saved frame 600
# Saved frame 660
# Saved frame 720
# Saved frame 780
# Saved frame 840
# Saved frame 900
# Saved frame 960
# Saved frame 1020
# Saved frame 1080
# Saved frame 1140
# Saved frame 1200
# Saved frame 1260
# Saved frame 1320
# Saved frame 1380
# Saved frame 1440
# Saved frame 1500
# Saved frame 1560
# Saved frame 1620
# Saved frame 1680
# Saved frame 1740
# Saved frame 1800
# Saved frame 1860
# Saved frame 1920
# Saved frame 1980
# Saved frame 2040
# Saved frame 2100
# Saved frame 2160
# Saved frame 2220
# Saved frame 2280
# Saved frame 2340
# Saved frame 2400
# Saved frame 2460
# Saved frame 2520
# Saved frame 2580
# Saved frame 2640
# Saved frame 2700
# Saved frame 2760
# Saved frame 2820
# Saved frame 2880
# Saved frame 2940
# Saved frame 3000
# Saved frame 3060
# Saved frame 3120
# Saved frame 3180
# Saved frame 3240
# Saved frame 3300
# Saved frame 3360
# Saved frame 3420
# Saved frame 3480
# Saved frame 3540
# Saved frame 3600
# Saved frame 3660
# Saved frame 3720
# Saved frame 3780
# Saved frame 3840
# Saved frame 3900
# Saved frame 3960
# Saved frame 4020
# Saved frame 4080
# Saved frame 4140
# Saved frame 4200
# Saved frame 4260
# Saved frame 4320
# Saved frame 4380
# Saved frame 4440
# Saved frame 4500
# Saved frame 4560
# Saved frame 4620
# Saved frame 4680
# Saved frame 4740
# Saved frame 4800
# Saved frame 4860
# Saved frame 4920
# Saved frame 4980
# Saved frame 5040
# Saved frame 5100
# Saved frame 5160
# Saved frame 5220
# Saved frame 5280
# Saved frame 5340
# Saved frame 5400
# Saved frame 5460
# Saved frame 5520
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# Saved frame 450
# Saved frame 480
# Saved frame 510
# Saved frame 540
# Saved frame 570
# Saved frame 600
# Saved frame 630
# Saved frame 660
# Saved frame 690
# Saved frame 720
# Saved frame 750
# Saved frame 780
# Saved frame 810
# Saved frame 840
# Saved frame 870
# Saved frame 900
# Saved frame 930
# Saved frame 960
# Saved frame 990
# Saved frame 1020
# Saved frame 1050
# Saved frame 1080
# Saved frame 1110
# Saved frame 1140
# Saved frame 1170
# Saved frame 1200
# Saved frame 1230
# Saved frame 1260
# Saved frame 1290
# Saved frame 1320
# Saved frame 1350
# Saved frame 1380
# Saved frame 1410
# Saved frame 1440
# Saved frame 1470
# Saved frame 1500
# Saved frame 1530
# Saved frame 1560
# Saved frame 1590
# Saved frame 1620
# Saved frame 1650
# Saved frame 1680
# Saved frame 1710
# Saved frame 1740
# Saved frame 1770
# Saved frame 1800
# Saved frame 1830
# Saved frame 1860
# Saved frame 1890
# Saved frame 1920
# Saved frame 1950
# Saved frame 1980
# Saved frame 2010
# Saved frame 2040
# Saved frame 2070
# Saved frame 2100
# Saved frame 2130
# Saved frame 2160
# Saved frame 2190
# Saved frame 2220
# Saved frame 2250
# Saved frame 2280
# Saved frame 2310
# Saved frame 2340
# Saved frame 2370
# Saved frame 2400
# Saved frame 2430
# Saved frame 2460
# Saved frame 2490
# Saved frame 2520
# Saved frame 2550
# Saved frame 2580
# Saved frame 2610
# Saved frame 2640
# Saved frame 2670
# Saved frame 2700
# Saved frame 2730
# Saved frame 2760
# Saved frame 2790
# Saved frame 2820
# Saved frame 2850
# Saved frame 2880
# Saved frame 2910
# Saved frame 2940
# Saved frame 2970
# Saved frame 3000
# Saved frame 3030
# Saved frame 3060
# Saved frame 3090
# Saved frame 3120
# Saved frame 3150
# Saved frame 3180
# Saved frame 3210
# Saved frame 3240
# Saved frame 3270
# Saved frame 3300
# Saved frame 3330
# Saved frame 3360
# Saved frame 3390
# Saved frame 3420
# Saved frame 3450
# Saved frame 3480
# Saved frame 3510
# Saved frame 3540
# Saved frame 3570
# Saved frame 3600
# Saved frame 3630
# Saved frame 3660
# Saved frame 3690
# Saved frame 3720
# Saved frame 3750
# Saved frame 3780
# Saved frame 3810
# Saved frame 3840
# Saved frame 3870
# Saved frame 3900
# Saved frame 3930
# Saved frame 3960
# Saved frame 3990
# Saved frame 4020
# Saved frame 4050
# Saved frame 4080
# Saved frame 4110
# Saved frame 4140
# Saved frame 4170
# Saved frame 4200
# Saved frame 4230
# Saved frame 4260
# Saved frame 4290
# Saved frame 4320
# Saved frame 4350
# Saved frame 4380
# Saved frame 4410
# Saved frame 4440
# Saved frame 4470
# Saved frame 4500
# Saved frame 4530
# Saved frame 4560
# Saved frame 4590
# Saved frame 4620
# Saved frame 4650
# Saved frame 4680
# Saved frame 4710
# Saved frame 4740
# Saved frame 4770
# Saved frame 4800
# Saved frame 4830
# Saved frame 4860
# Saved frame 4890
# Saved frame 4920
# Saved frame 4950
# Saved frame 4980
# Saved frame 5010
# Saved frame 5040
# Saved frame 5070
# Saved frame 5100
# Saved frame 5130
# Saved frame 5160
# Saved frame 5190
# Saved frame 5220
# Saved frame 5250
# Saved frame 5280
# Saved frame 5310
# Saved frame 5340
# Saved frame 5370
# Saved frame 5400
# Saved frame 5430
# Saved frame 5460
# Saved frame 5490
# Saved frame 5520
# Saved frame 5550
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 15
# Saved frame 30
# Saved frame 45
# Saved frame 60
# Saved frame 75
# Saved frame 90
# Saved frame 105
# Saved frame 120
# Saved frame 135
# Saved frame 150
# Saved frame 165
# Saved frame 180
# Saved frame 195
# Saved frame 210
# Saved frame 225
# Saved frame 240
# Saved frame 255
# Saved frame 270
# Saved frame 285
# Saved frame 300
# Saved frame 315
# Saved frame 330
# Saved frame 345
# Saved frame 360
# Saved frame 375
# Saved frame 390
# Saved frame 405
# Saved frame 420
# Saved frame 435
# Saved frame 450
# Saved frame 465
# Saved frame 480
# Saved frame 495
# Saved frame 510
# Saved frame 525
# Saved frame 540
# Saved frame 555
# Saved frame 570
# Saved frame 585
# Saved frame 600
# Saved frame 615
# Saved frame 630
# Saved frame 645
# Saved frame 660
# Saved frame 675
# Saved frame 690
# Saved frame 705
# Saved frame 720
# Saved frame 735
# Saved frame 750
# Saved frame 765
# Saved frame 780
# Saved frame 795
# Saved frame 810
# Saved frame 825
# Saved frame 840
# Saved frame 855
# Saved frame 870
# Saved frame 885
# Saved frame 900
# Saved frame 915
# Saved frame 930
# Saved frame 945
# Saved frame 960
# Saved frame 975
# Saved frame 990
# Saved frame 1005
# Saved frame 1020
# Saved frame 1035
# Saved frame 1050
# Saved frame 1065
# Saved frame 1080
# Saved frame 1095
# Saved frame 1110
# Saved frame 1125
# Saved frame 1140
# Saved frame 1155
# Saved frame 1170
# Saved frame 1185
# Saved frame 1200
# Saved frame 1215
# Saved frame 1230
# Saved frame 1245
# Saved frame 1260
# Saved frame 1275
# Saved frame 1290
# Saved frame 1305
# Saved frame 1320
# Saved frame 1335
# Saved frame 1350
# Saved frame 1365
# Saved frame 1380
# Saved frame 1395
# Saved frame 1410
# Saved frame 1425
# Saved frame 1440
# Saved frame 1455
# Saved frame 1470
# Saved frame 1485
# Saved frame 1500
# Saved frame 1515
# Saved frame 1530
# Saved frame 1545
# Saved frame 1560
# Saved frame 1575
# Saved frame 1590
# Saved frame 1605
# Saved frame 1620
# Saved frame 1635
# Saved frame 1650
# Saved frame 1665
# Saved frame 1680
# Saved frame 1695
# Saved frame 1710
# Saved frame 1725
# Saved frame 1740
# Saved frame 1755
# Saved frame 1770
# Saved frame 1785
# Saved frame 1800
# Saved frame 1815
# Saved frame 1830
# Saved frame 1845
# Saved frame 1860
# Saved frame 1875
# Saved frame 1890
# Saved frame 1905
# Saved frame 1920
# Saved frame 1935
# Saved frame 1950
# Saved frame 1965
# Saved frame 1980
# Saved frame 1995
# Saved frame 2010
# Saved frame 2025
# Saved frame 2040
# Saved frame 2055
# Saved frame 2070
# Saved frame 2085
# Saved frame 2100
# Saved frame 2115
# Saved frame 2130
# Saved frame 2145
# Saved frame 2160
# Saved frame 2175
# Saved frame 2190
# Saved frame 2205
# Saved frame 2220
# Saved frame 2235
# Saved frame 2250
# Saved frame 2265
# Saved frame 2280
# Saved frame 2295
# Saved frame 2310
# Saved frame 2325
# Saved frame 2340
# Saved frame 2355
# Saved frame 2370
# Saved frame 2385
# Saved frame 2400
# Saved frame 2415
# Saved frame 2430
# Saved frame 2445
# Saved frame 2460
# Saved frame 2475
# Saved frame 2490
# Saved frame 2505
# Saved frame 2520
# Saved frame 2535
# Saved frame 2550
# Saved frame 2565
# Saved frame 2580
# Saved frame 2595
# Saved frame 2610
# Saved frame 2625
# Saved frame 2640
# Saved frame 2655
# Saved frame 2670
# Saved frame 2685
# Saved frame 2700
# Saved frame 2715
# Saved frame 2730
# Saved frame 2745
# Saved frame 2760
# Saved frame 2775
# Saved frame 2790
# Saved frame 2805
# Saved frame 2820
# Saved frame 2835
# Saved frame 2850
# Saved frame 2865
# Saved frame 2880
# Saved frame 2895
# Saved frame 2910
# Saved frame 2925
# Saved frame 2940
# Saved frame 2955
# Saved frame 2970
# Saved frame 2985
# Saved frame 3000
# Saved frame 3015
# Saved frame 3030
# Saved frame 3045
# Saved frame 3060
# Saved frame 3075
# Saved frame 3090
# Saved frame 3105
# Saved frame 3120
# Saved frame 3135
# Saved frame 3150
# Saved frame 3165
# Saved frame 3180
# Saved frame 3195
# Saved frame 3210
# Saved frame 3225
# Saved frame 3240
# Saved frame 3255
# Saved frame 3270
# Saved frame 3285
# Saved frame 3300
# Saved frame 3315
# Saved frame 3330
# Saved frame 3345
# Saved frame 3360
# Saved frame 3375
# Saved frame 3390
# Saved frame 3405
# Saved frame 3420
# Saved frame 3435
# Saved frame 3450
# Saved frame 3465
# Saved frame 3480
# Saved frame 3495
# Saved frame 3510
# Saved frame 3525
# Saved frame 3540
# Saved frame 3555
# Saved frame 3570
# Saved frame 3585
# Saved frame 3600
# Saved frame 3615
# Saved frame 3630
# Saved frame 3645
# Saved frame 3660
# Saved frame 3675
# Saved frame 3690
# Saved frame 3705
# Saved frame 3720
# Saved frame 3735
# Saved frame 3750
# Saved frame 3765
# Saved frame 3780
# Saved frame 3795
# Saved frame 3810
# Saved frame 3825
# Saved frame 3840
# Saved frame 3855
# Saved frame 3870
# Saved frame 3885
# Saved frame 3900
# Saved frame 3915
# Saved frame 3930
# Saved frame 3945
# Saved frame 3960
# Saved frame 3975
# Saved frame 3990
# Saved frame 4005
# Saved frame 4020
# Saved frame 4035
# Saved frame 4050
# Saved frame 4065
# Saved frame 4080
# Saved frame 4095
# Saved frame 4110
# Saved frame 4125
# Saved frame 4140
# Saved frame 4155
# Saved frame 4170
# Saved frame 4185
# Saved frame 4200
# Saved frame 4215
# Saved frame 4230
# Saved frame 4245
# Saved frame 4260
# Saved frame 4275
# Saved frame 4290
# Saved frame 4305
# Saved frame 4320
# Saved frame 4335
# Saved frame 4350
# Saved frame 4365
# Saved frame 4380
# Saved frame 4395
# Saved frame 4410
# Saved frame 4425
# Saved frame 4440
# Saved frame 4455
# Saved frame 4470
# Saved frame 4485
# Saved frame 4500
# Saved frame 4515
# Saved frame 4530
# Saved frame 4545
# Saved frame 4560
# Saved frame 4575
# Saved frame 4590
# Saved frame 4605
# Saved frame 4620
# Saved frame 4635
# Saved frame 4650
# Saved frame 4665
# Saved frame 4680
# Saved frame 4695
# Saved frame 4710
# Saved frame 4725
# Saved frame 4740
# Saved frame 4755
# Saved frame 4770
# Saved frame 4785
# Saved frame 4800
# Saved frame 4815
# Saved frame 4830
# Saved frame 4845
# Saved frame 4860
# Saved frame 4875
# Saved frame 4890
# Saved frame 4905
# Saved frame 4920
# Saved frame 4935
# Saved frame 4950
# Saved frame 4965
# Saved frame 4980
# Saved frame 4995
# Saved frame 5010
# Saved frame 5025
# Saved frame 5040
# Saved frame 5055
# Saved frame 5070
# Saved frame 5085
# Saved frame 5100
# Saved frame 5115
# Saved frame 5130
# Saved frame 5145
# Saved frame 5160
# Saved frame 5175
# Saved frame 5190
# Saved frame 5205
# Saved frame 5220
# Saved frame 5235
# Saved frame 5250
# Saved frame 5265
# Saved frame 5280
# Saved frame 5295
# Saved frame 5310
# Saved frame 5325
# Saved frame 5340
# Saved frame 5355
# Saved frame 5370
# Saved frame 5385
# Saved frame 5400
# Saved frame 5415
# Saved frame 5430
# Saved frame 5445
# Saved frame 5460
# Saved frame 5475
# Saved frame 5490
# Saved frame 5505
# Saved frame 5520
# Saved frame 5535
# Saved frame 5550
# Saved frame 5565
# extracting at 5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 6
# Saved frame 12
# Saved frame 18
# Saved frame 24
# Saved frame 30
# Saved frame 36
# Saved frame 42
# Saved frame 48
# Saved frame 54
# Saved frame 60
# Saved frame 66
# Saved frame 72
# Saved frame 78
# Saved frame 84
# Saved frame 90
# Saved frame 96
# Saved frame 102
# Saved frame 108
# Saved frame 114
# Saved frame 120
# Saved frame 126
# Saved frame 132
# Saved frame 138
# Saved frame 144
# Saved frame 150
# Saved frame 156
# Saved frame 162
# Saved frame 168
# Saved frame 174
# Saved frame 180
# Saved frame 186
# Saved frame 192
# Saved frame 198
# Saved frame 204
# Saved frame 210
# Saved frame 216
# Saved frame 222
# Saved frame 228
# Saved frame 234
# Saved frame 240
# Saved frame 246
# Saved frame 252
# Saved frame 258
# Saved frame 264
# Saved frame 270
# Saved frame 276
# Saved frame 282
# Saved frame 288
# Saved frame 294
# Saved frame 300
# Saved frame 306
# Saved frame 312
# Saved frame 318
# Saved frame 324
# Saved frame 330
# Saved frame 336
# Saved frame 342
# Saved frame 348
# Saved frame 354
# Saved frame 360
# Saved frame 366
# Saved frame 372
# Saved frame 378
# Saved frame 384
# Saved frame 390
# Saved frame 396
# Saved frame 402
# Saved frame 408
# Saved frame 414
# Saved frame 420
# Saved frame 426
# Saved frame 432
# Saved frame 438
# Saved frame 444
# Saved frame 450
# Saved frame 456
# Saved frame 462
# Saved frame 468
# Saved frame 474
# Saved frame 480
# Saved frame 486
# Saved frame 492
# Saved frame 498
# Saved frame 504
# Saved frame 510
# Saved frame 516
# Saved frame 522
# Saved frame 528
# Saved frame 534
# Saved frame 540
# Saved frame 546
# Saved frame 552
# Saved frame 558
# Saved frame 564
# Saved frame 570
# Saved frame 576
# Saved frame 582
# Saved frame 588
# Saved frame 594
# Saved frame 600
# Saved frame 606
# Saved frame 612
# Saved frame 618
# Saved frame 624
# Saved frame 630
# Saved frame 636
# Saved frame 642
# Saved frame 648
# Saved frame 654
# Saved frame 660
# Saved frame 666
# Saved frame 672
# Saved frame 678
# Saved frame 684
# Saved frame 690
# Saved frame 696
# Saved frame 702
# Saved frame 708
# Saved frame 714
# Saved frame 720
# Saved frame 726
# Saved frame 732
# Saved frame 738
# Saved frame 744
# Saved frame 750
# Saved frame 756
# Saved frame 762
# Saved frame 768
# Saved frame 774
# Saved frame 780
# Saved frame 786
# Saved frame 792
# Saved frame 798
# Saved frame 804
# Saved frame 810
# Saved frame 816
# Saved frame 822
# Saved frame 828
# Saved frame 834
# Saved frame 840
# Saved frame 846
# Saved frame 852
# Saved frame 858
# Saved frame 864
# Saved frame 870
# Saved frame 876
# Saved frame 882
# Saved frame 888
# Saved frame 894
# Saved frame 900
# Saved frame 906
# Saved frame 912
# Saved frame 918
# Saved frame 924
# Saved frame 930
# Saved frame 936
# Saved frame 942
# Saved frame 948
# Saved frame 954
# Saved frame 960
# Saved frame 966
# Saved frame 972
# Saved frame 978
# Saved frame 984
# Saved frame 990
# Saved frame 996
# Saved frame 1002
# Saved frame 1008
# Saved frame 1014
# Saved frame 1020
# Saved frame 1026
# Saved frame 1032
# Saved frame 1038
# Saved frame 1044
# Saved frame 1050
# Saved frame 1056
# Saved frame 1062
# Saved frame 1068
# Saved frame 1074
# Saved frame 1080
# Saved frame 1086
# Saved frame 1092
# Saved frame 1098
# Saved frame 1104
# Saved frame 1110
# Saved frame 1116
# Saved frame 1122
# Saved frame 1128
# Saved frame 1134
# Saved frame 1140
# Saved frame 1146
# Saved frame 1152
# Saved frame 1158
# Saved frame 1164
# Saved frame 1170
# Saved frame 1176
# Saved frame 1182
# Saved frame 1188
# Saved frame 1194
# Saved frame 1200
# Saved frame 1206
# Saved frame 1212
# Saved frame 1218
# Saved frame 1224
# Saved frame 1230
# Saved frame 1236
# Saved frame 1242
# Saved frame 1248
# Saved frame 1254
# Saved frame 1260
# Saved frame 1266
# Saved frame 1272
# Saved frame 1278
# Saved frame 1284
# Saved frame 1290
# Saved frame 1296
# Saved frame 1302
# Saved frame 1308
# Saved frame 1314
# Saved frame 1320
# Saved frame 1326
# Saved frame 1332
# Saved frame 1338
# Saved frame 1344
# Saved frame 1350
# Saved frame 1356
# Saved frame 1362
# Saved frame 1368
# Saved frame 1374
# Saved frame 1380
# Saved frame 1386
# Saved frame 1392
# Saved frame 1398
# Saved frame 1404
# Saved frame 1410
# Saved frame 1416
# Saved frame 1422
# Saved frame 1428
# Saved frame 1434
# Saved frame 1440
# Saved frame 1446
# Saved frame 1452
# Saved frame 1458
# Saved frame 1464
# Saved frame 1470
# Saved frame 1476
# Saved frame 1482
# Saved frame 1488
# Saved frame 1494
# Saved frame 1500
# Saved frame 1506
# Saved frame 1512
# Saved frame 1518
# Saved frame 1524
# Saved frame 1530
# Saved frame 1536
# Saved frame 1542
# Saved frame 1548
# Saved frame 1554
# Saved frame 1560
# Saved frame 1566
# Saved frame 1572
# Saved frame 1578
# Saved frame 1584
# Saved frame 1590
# Saved frame 1596
# Saved frame 1602
# Saved frame 1608
# Saved frame 1614
# Saved frame 1620
# Saved frame 1626
# Saved frame 1632
# Saved frame 1638
# Saved frame 1644
# Saved frame 1650
# Saved frame 1656
# Saved frame 1662
# Saved frame 1668
# Saved frame 1674
# Saved frame 1680
# Saved frame 1686
# Saved frame 1692
# Saved frame 1698
# Saved frame 1704
# Saved frame 1710
# Saved frame 1716
# Saved frame 1722
# Saved frame 1728
# Saved frame 1734
# Saved frame 1740
# Saved frame 1746
# Saved frame 1752
# Saved frame 1758
# Saved frame 1764
# Saved frame 1770
# Saved frame 1776
# Saved frame 1782
# Saved frame 1788
# Saved frame 1794
# Saved frame 1800
# Saved frame 1806
# Saved frame 1812
# Saved frame 1818
# Saved frame 1824
# Saved frame 1830
# Saved frame 1836
# Saved frame 1842
# Saved frame 1848
# Saved frame 1854
# Saved frame 1860
# Saved frame 1866
# Saved frame 1872
# Saved frame 1878
# Saved frame 1884
# Saved frame 1890
# Saved frame 1896
# Saved frame 1902
# Saved frame 1908
# Saved frame 1914
# Saved frame 1920
# Saved frame 1926
# Saved frame 1932
# Saved frame 1938
# Saved frame 1944
# Saved frame 1950
# Saved frame 1956
# Saved frame 1962
# Saved frame 1968
# Saved frame 1974
# Saved frame 1980
# Saved frame 1986
# Saved frame 1992
# Saved frame 1998
# Saved frame 2004
# Saved frame 2010
# Saved frame 2016
# Saved frame 2022
# Saved frame 2028
# Saved frame 2034
# Saved frame 2040
# Saved frame 2046
# Saved frame 2052
# Saved frame 2058
# Saved frame 2064
# Saved frame 2070
# Saved frame 2076
# Saved frame 2082
# Saved frame 2088
# Saved frame 2094
# Saved frame 2100
# Saved frame 2106
# Saved frame 2112
# Saved frame 2118
# Saved frame 2124
# Saved frame 2130
# Saved frame 2136
# Saved frame 2142
# Saved frame 2148
# Saved frame 2154
# Saved frame 2160
# Saved frame 2166
# Saved frame 2172
# Saved frame 2178
# Saved frame 2184
# Saved frame 2190
# Saved frame 2196
# Saved frame 2202
# Saved frame 2208
# Saved frame 2214
# Saved frame 2220
# Saved frame 2226
# Saved frame 2232
# Saved frame 2238
# Saved frame 2244
# Saved frame 2250
# Saved frame 2256
# Saved frame 2262
# Saved frame 2268
# Saved frame 2274
# Saved frame 2280
# Saved frame 2286
# Saved frame 2292
# Saved frame 2298
# Saved frame 2304
# Saved frame 2310
# Saved frame 2316
# Saved frame 2322
# Saved frame 2328
# Saved frame 2334
# Saved frame 2340
# Saved frame 2346
# Saved frame 2352
# Saved frame 2358
# Saved frame 2364
# Saved frame 2370
# Saved frame 2376
# Saved frame 2382
# Saved frame 2388
# Saved frame 2394
# Saved frame 2400
# Saved frame 2406
# Saved frame 2412
# Saved frame 2418
# Saved frame 2424
# Saved frame 2430
# Saved frame 2436
# Saved frame 2442
# Saved frame 2448
# Saved frame 2454
# Saved frame 2460
# Saved frame 2466
# Saved frame 2472
# Saved frame 2478
# Saved frame 2484
# Saved frame 2490
# Saved frame 2496
# Saved frame 2502
# Saved frame 2508
# Saved frame 2514
# Saved frame 2520
# Saved frame 2526
# Saved frame 2532
# Saved frame 2538
# Saved frame 2544
# Saved frame 2550
# Saved frame 2556
# Saved frame 2562
# Saved frame 2568
# Saved frame 2574
# Saved frame 2580
# Saved frame 2586
# Saved frame 2592
# Saved frame 2598
# Saved frame 2604
# Saved frame 2610
# Saved frame 2616
# Saved frame 2622
# Saved frame 2628
# Saved frame 2634
# Saved frame 2640
# Saved frame 2646
# Saved frame 2652
# Saved frame 2658
# Saved frame 2664
# Saved frame 2670
# Saved frame 2676
# Saved frame 2682
# Saved frame 2688
# Saved frame 2694
# Saved frame 2700
# Saved frame 2706
# Saved frame 2712
# Saved frame 2718
# Saved frame 2724
# Saved frame 2730
# Saved frame 2736
# Saved frame 2742
# Saved frame 2748
# Saved frame 2754
# Saved frame 2760
# Saved frame 2766
# Saved frame 2772
# Saved frame 2778
# Saved frame 2784
# Saved frame 2790
# Saved frame 2796
# Saved frame 2802
# Saved frame 2808
# Saved frame 2814
# Saved frame 2820
# Saved frame 2826
# Saved frame 2832
# Saved frame 2838
# Saved frame 2844
# Saved frame 2850
# Saved frame 2856
# Saved frame 2862
# Saved frame 2868
# Saved frame 2874
# Saved frame 2880
# Saved frame 2886
# Saved frame 2892
# Saved frame 2898
# Saved frame 2904
# Saved frame 2910
# Saved frame 2916
# Saved frame 2922
# Saved frame 2928
# Saved frame 2934
# Saved frame 2940
# Saved frame 2946
# Saved frame 2952
# Saved frame 2958
# Saved frame 2964
# Saved frame 2970
# Saved frame 2976
# Saved frame 2982
# Saved frame 2988
# Saved frame 2994
# Saved frame 3000
# Saved frame 3006
# Saved frame 3012
# Saved frame 3018
# Saved frame 3024
# Saved frame 3030
# Saved frame 3036
# Saved frame 3042
# Saved frame 3048
# Saved frame 3054
# Saved frame 3060
# Saved frame 3066
# Saved frame 3072
# Saved frame 3078
# Saved frame 3084
# Saved frame 3090
# Saved frame 3096
# Saved frame 3102
# Saved frame 3108
# Saved frame 3114
# Saved frame 3120
# Saved frame 3126
# Saved frame 3132
# Saved frame 3138
# Saved frame 3144
# Saved frame 3150
# Saved frame 3156
# Saved frame 3162
# Saved frame 3168
# Saved frame 3174
# Saved frame 3180
# Saved frame 3186
# Saved frame 3192
# Saved frame 3198
# Saved frame 3204
# Saved frame 3210
# Saved frame 3216
# Saved frame 3222
# Saved frame 3228
# Saved frame 3234
# Saved frame 3240
# Saved frame 3246
# Saved frame 3252
# Saved frame 3258
# Saved frame 3264
# Saved frame 3270
# Saved frame 3276
# Saved frame 3282
# Saved frame 3288
# Saved frame 3294
# Saved frame 3300
# Saved frame 3306
# Saved frame 3312
# Saved frame 3318
# Saved frame 3324
# Saved frame 3330
# Saved frame 3336
# Saved frame 3342
# Saved frame 3348
# Saved frame 3354
# Saved frame 3360
# Saved frame 3366
# Saved frame 3372
# Saved frame 3378
# Saved frame 3384
# Saved frame 3390
# Saved frame 3396
# Saved frame 3402
# Saved frame 3408
# Saved frame 3414
# Saved frame 3420
# Saved frame 3426
# Saved frame 3432
# Saved frame 3438
# Saved frame 3444
# Saved frame 3450
# Saved frame 3456
# Saved frame 3462
# Saved frame 3468
# Saved frame 3474
# Saved frame 3480
# Saved frame 3486
# Saved frame 3492
# Saved frame 3498
# Saved frame 3504
# Saved frame 3510
# Saved frame 3516
# Saved frame 3522
# Saved frame 3528
# Saved frame 3534
# Saved frame 3540
# Saved frame 3546
# Saved frame 3552
# Saved frame 3558
# Saved frame 3564
# Saved frame 3570
# Saved frame 3576
# Saved frame 3582
# Saved frame 3588
# Saved frame 3594
# Saved frame 3600
# Saved frame 3606
# Saved frame 3612
# Saved frame 3618
# Saved frame 3624
# Saved frame 3630
# Saved frame 3636
# Saved frame 3642
# Saved frame 3648
# Saved frame 3654
# Saved frame 3660
# Saved frame 3666
# Saved frame 3672
# Saved frame 3678
# Saved frame 3684
# Saved frame 3690
# Saved frame 3696
# Saved frame 3702
# Saved frame 3708
# Saved frame 3714
# Saved frame 3720
# Saved frame 3726
# Saved frame 3732
# Saved frame 3738
# Saved frame 3744
# Saved frame 3750
# Saved frame 3756
# Saved frame 3762
# Saved frame 3768
# Saved frame 3774
# Saved frame 3780
# Saved frame 3786
# Saved frame 3792
# Saved frame 3798
# Saved frame 3804
# Saved frame 3810
# Saved frame 3816
# Saved frame 3822
# Saved frame 3828
# Saved frame 3834
# Saved frame 3840
# Saved frame 3846
# Saved frame 3852
# Saved frame 3858
# Saved frame 3864
# Saved frame 3870
# Saved frame 3876
# Saved frame 3882
# Saved frame 3888
# Saved frame 3894
# Saved frame 3900
# Saved frame 3906
# Saved frame 3912
# Saved frame 3918
# Saved frame 3924
# Saved frame 3930
# Saved frame 3936
# Saved frame 3942
# Saved frame 3948
# Saved frame 3954
# Saved frame 3960
# Saved frame 3966
# Saved frame 3972
# Saved frame 3978
# Saved frame 3984
# Saved frame 3990
# Saved frame 3996
# Saved frame 4002
# Saved frame 4008
# Saved frame 4014
# Saved frame 4020
# Saved frame 4026
# Saved frame 4032
# Saved frame 4038
# Saved frame 4044
# Saved frame 4050
# Saved frame 4056
# Saved frame 4062
# Saved frame 4068
# Saved frame 4074
# Saved frame 4080
# Saved frame 4086
# Saved frame 4092
# Saved frame 4098
# Saved frame 4104
# Saved frame 4110
# Saved frame 4116
# Saved frame 4122
# Saved frame 4128
# Saved frame 4134
# Saved frame 4140
# Saved frame 4146
# Saved frame 4152
# Saved frame 4158
# Saved frame 4164
# Saved frame 4170
# Saved frame 4176
# Saved frame 4182
# Saved frame 4188
# Saved frame 4194
# Saved frame 4200
# Saved frame 4206
# Saved frame 4212
# Saved frame 4218
# Saved frame 4224
# Saved frame 4230
# Saved frame 4236
# Saved frame 4242
# Saved frame 4248
# Saved frame 4254
# Saved frame 4260
# Saved frame 4266
# Saved frame 4272
# Saved frame 4278
# Saved frame 4284
# Saved frame 4290
# Saved frame 4296
# Saved frame 4302
# Saved frame 4308
# Saved frame 4314
# Saved frame 4320
# Saved frame 4326
# Saved frame 4332
# Saved frame 4338
# Saved frame 4344
# Saved frame 4350
# Saved frame 4356
# Saved frame 4362
# Saved frame 4368
# Saved frame 4374
# Saved frame 4380
# Saved frame 4386
# Saved frame 4392
# Saved frame 4398
# Saved frame 4404
# Saved frame 4410
# Saved frame 4416
# Saved frame 4422
# Saved frame 4428
# Saved frame 4434
# Saved frame 4440
# Saved frame 4446
# Saved frame 4452
# Saved frame 4458
# Saved frame 4464
# Saved frame 4470
# Saved frame 4476
# Saved frame 4482
# Saved frame 4488
# Saved frame 4494
# Saved frame 4500
# Saved frame 4506
# Saved frame 4512
# Saved frame 4518
# Saved frame 4524
# Saved frame 4530
# Saved frame 4536
# Saved frame 4542
# Saved frame 4548
# Saved frame 4554
# Saved frame 4560
# Saved frame 4566
# Saved frame 4572
# Saved frame 4578
# Saved frame 4584
# Saved frame 4590
# Saved frame 4596
# Saved frame 4602
# Saved frame 4608
# Saved frame 4614
# Saved frame 4620
# Saved frame 4626
# Saved frame 4632
# Saved frame 4638
# Saved frame 4644
# Saved frame 4650
# Saved frame 4656
# Saved frame 4662
# Saved frame 4668
# Saved frame 4674
# Saved frame 4680
# Saved frame 4686
# Saved frame 4692
# Saved frame 4698
# Saved frame 4704
# Saved frame 4710
# Saved frame 4716
# Saved frame 4722
# Saved frame 4728
# Saved frame 4734
# Saved frame 4740
# Saved frame 4746
# Saved frame 4752
# Saved frame 4758
# Saved frame 4764
# Saved frame 4770
# Saved frame 4776
# Saved frame 4782
# Saved frame 4788
# Saved frame 4794
# Saved frame 4800
# Saved frame 4806
# Saved frame 4812
# Saved frame 4818
# Saved frame 4824
# Saved frame 4830
# Saved frame 4836
# Saved frame 4842
# Saved frame 4848
# Saved frame 4854
# Saved frame 4860
# Saved frame 4866
# Saved frame 4872
# Saved frame 4878
# Saved frame 4884
# Saved frame 4890
# Saved frame 4896
# Saved frame 4902
# Saved frame 4908
# Saved frame 4914
# Saved frame 4920
# Saved frame 4926
# Saved frame 4932
# Saved frame 4938
# Saved frame 4944
# Saved frame 4950
# Saved frame 4956
# Saved frame 4962
# Saved frame 4968
# Saved frame 4974
# Saved frame 4980
# Saved frame 4986
# Saved frame 4992
# Saved frame 4998
# Saved frame 5004
# Saved frame 5010
# Saved frame 5016
# Saved frame 5022
# Saved frame 5028
# Saved frame 5034
# Saved frame 5040
# Saved frame 5046
# Saved frame 5052
# Saved frame 5058
# Saved frame 5064
# Saved frame 5070
# Saved frame 5076
# Saved frame 5082
# Saved frame 5088
# Saved frame 5094
# Saved frame 5100
# Saved frame 5106
# Saved frame 5112
# Saved frame 5118
# Saved frame 5124
# Saved frame 5130
# Saved frame 5136
# Saved frame 5142
# Saved frame 5148
# Saved frame 5154
# Saved frame 5160
# Saved frame 5166
# Saved frame 5172
# Saved frame 5178
# Saved frame 5184
# Saved frame 5190
# Saved frame 5196
# Saved frame 5202
# Saved frame 5208
# Saved frame 5214
# Saved frame 5220
# Saved frame 5226
# Saved frame 5232
# Saved frame 5238
# Saved frame 5244
# Saved frame 5250
# Saved frame 5256
# Saved frame 5262
# Saved frame 5268
# Saved frame 5274
# Saved frame 5280
# Saved frame 5286
# Saved frame 5292
# Saved frame 5298
# Saved frame 5304
# Saved frame 5310
# Saved frame 5316
# Saved frame 5322
# Saved frame 5328
# Saved frame 5334
# Saved frame 5340
# Saved frame 5346
# Saved frame 5352
# Saved frame 5358
# Saved frame 5364
# Saved frame 5370
# Saved frame 5376
# Saved frame 5382
# Saved frame 5388
# Saved frame 5394
# Saved frame 5400
# Saved frame 5406
# Saved frame 5412
# Saved frame 5418
# Saved frame 5424
# Saved frame 5430
# Saved frame 5436
# Saved frame 5442
# Saved frame 5448
# Saved frame 5454
# Saved frame 5460
# Saved frame 5466
# Saved frame 5472
# Saved frame 5478
# Saved frame 5484
# Saved frame 5490
# Saved frame 5496
# Saved frame 5502
# Saved frame 5508
# Saved frame 5514
# Saved frame 5520
# Saved frame 5526
# Saved frame 5532
# Saved frame 5538
# Saved frame 5544
# Saved frame 5550
# Saved frame 5556
# Saved frame 5562
# Saved frame 5568
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 59.940060474943195
# Saved frame 0
# Saved frame 120
# Saved frame 240
# Saved frame 360
# Saved frame 480
# Saved frame 600
# Saved frame 720
# Saved frame 840
# Saved frame 960
# Saved frame 1080
# Saved frame 1200
# Saved frame 1320
# Saved frame 1440
# Saved frame 1560
# Saved frame 1680
# Saved frame 1800
# Saved frame 1920
# Saved frame 2040
# Saved frame 2160
# Saved frame 2280
# Saved frame 2400
# Saved frame 2520
# Saved frame 2640
# Saved frame 2760
# Saved frame 2880
# Saved frame 3000
# Saved frame 3120
# Saved frame 3240
# Saved frame 3360
# Saved frame 3480
# Saved frame 3600
# Saved frame 3720
# Saved frame 3840
# Saved frame 3960
# Saved frame 4080
# Saved frame 4200
# Saved frame 4320
# Saved frame 4440
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 59.940060474943195
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# Saved frame 480
# Saved frame 540
# Saved frame 600
# Saved frame 660
# Saved frame 720
# Saved frame 780
# Saved frame 840
# Saved frame 900
# Saved frame 960
# Saved frame 1020
# Saved frame 1080
# Saved frame 1140
# Saved frame 1200
# Saved frame 1260
# Saved frame 1320
# Saved frame 1380
# Saved frame 1440
# Saved frame 1500
# Saved frame 1560
# Saved frame 1620
# Saved frame 1680
# Saved frame 1740
# Saved frame 1800
# Saved frame 1860
# Saved frame 1920
# Saved frame 1980
# Saved frame 2040
# Saved frame 2100
# Saved frame 2160
# Saved frame 2220
# Saved frame 2280
# Saved frame 2340
# Saved frame 2400
# Saved frame 2460
# Saved frame 2520
# Saved frame 2580
# Saved frame 2640
# Saved frame 2700
# Saved frame 2760
# Saved frame 2820
# Saved frame 2880
# Saved frame 2940
# Saved frame 3000
# Saved frame 3060
# Saved frame 3120
# Saved frame 3180
# Saved frame 3240
# Saved frame 3300
# Saved frame 3360
# Saved frame 3420
# Saved frame 3480
# Saved frame 3540
# Saved frame 3600
# Saved frame 3660
# Saved frame 3720
# Saved frame 3780
# Saved frame 3840
# Saved frame 3900
# Saved frame 3960
# Saved frame 4020
# Saved frame 4080
# Saved frame 4140
# Saved frame 4200
# Saved frame 4260
# Saved frame 4320
# Saved frame 4380
# Saved frame 4440
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 59.940060474943195
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# Saved frame 450
# Saved frame 480
# Saved frame 510
# Saved frame 540
# Saved frame 570
# Saved frame 600
# Saved frame 630
# Saved frame 660
# Saved frame 690
# Saved frame 720
# Saved frame 750
# Saved frame 780
# Saved frame 810
# Saved frame 840
# Saved frame 870
# Saved frame 900
# Saved frame 930
# Saved frame 960
# Saved frame 990
# Saved frame 1020
# Saved frame 1050
# Saved frame 1080
# Saved frame 1110
# Saved frame 1140
# Saved frame 1170
# Saved frame 1200
# Saved frame 1230
# Saved frame 1260
# Saved frame 1290
# Saved frame 1320
# Saved frame 1350
# Saved frame 1380
# Saved frame 1410
# Saved frame 1440
# Saved frame 1470
# Saved frame 1500
# Saved frame 1530
# Saved frame 1560
# Saved frame 1590
# Saved frame 1620
# Saved frame 1650
# Saved frame 1680
# Saved frame 1710
# Saved frame 1740
# Saved frame 1770
# Saved frame 1800
# Saved frame 1830
# Saved frame 1860
# Saved frame 1890
# Saved frame 1920
# Saved frame 1950
# Saved frame 1980
# Saved frame 2010
# Saved frame 2040
# Saved frame 2070
# Saved frame 2100
# Saved frame 2130
# Saved frame 2160
# Saved frame 2190
# Saved frame 2220
# Saved frame 2250
# Saved frame 2280
# Saved frame 2310
# Saved frame 2340
# Saved frame 2370
# Saved frame 2400
# Saved frame 2430
# Saved frame 2460
# Saved frame 2490
# Saved frame 2520
# Saved frame 2550
# Saved frame 2580
# Saved frame 2610
# Saved frame 2640
# Saved frame 2670
# Saved frame 2700
# Saved frame 2730
# Saved frame 2760
# Saved frame 2790
# Saved frame 2820
# Saved frame 2850
# Saved frame 2880
# Saved frame 2910
# Saved frame 2940
# Saved frame 2970
# Saved frame 3000
# Saved frame 3030
# Saved frame 3060
# Saved frame 3090
# Saved frame 3120
# Saved frame 3150
# Saved frame 3180
# Saved frame 3210
# Saved frame 3240
# Saved frame 3270
# Saved frame 3300
# Saved frame 3330
# Saved frame 3360
# Saved frame 3390
# Saved frame 3420
# Saved frame 3450
# Saved frame 3480
# Saved frame 3510
# Saved frame 3540
# Saved frame 3570
# Saved frame 3600
# Saved frame 3630
# Saved frame 3660
# Saved frame 3690
# Saved frame 3720
# Saved frame 3750
# Saved frame 3780
# Saved frame 3810
# Saved frame 3840
# Saved frame 3870
# Saved frame 3900
# Saved frame 3930
# Saved frame 3960
# Saved frame 3990
# Saved frame 4020
# Saved frame 4050
# Saved frame 4080
# Saved frame 4110
# Saved frame 4140
# Saved frame 4170
# Saved frame 4200
# Saved frame 4230
# Saved frame 4260
# Saved frame 4290
# Saved frame 4320
# Saved frame 4350
# Saved frame 4380
# Saved frame 4410
# Saved frame 4440
# Saved frame 4470
# extracting at 5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 59.940060474943195
# Saved frame 0
# Saved frame 12
# Saved frame 24
# Saved frame 36
# Saved frame 48
# Saved frame 60
# Saved frame 72
# Saved frame 84
# Saved frame 96
# Saved frame 108
# Saved frame 120
# Saved frame 132
# Saved frame 144
# Saved frame 156
# Saved frame 168
# Saved frame 180
# Saved frame 192
# Saved frame 204
# Saved frame 216
# Saved frame 228
# Saved frame 240
# Saved frame 252
# Saved frame 264
# Saved frame 276
# Saved frame 288
# Saved frame 300
# Saved frame 312
# Saved frame 324
# Saved frame 336
# Saved frame 348
# Saved frame 360
# Saved frame 372
# Saved frame 384
# Saved frame 396
# Saved frame 408
# Saved frame 420
# Saved frame 432
# Saved frame 444
# Saved frame 456
# Saved frame 468
# Saved frame 480
# Saved frame 492
# Saved frame 504
# Saved frame 516
# Saved frame 528
# Saved frame 540
# Saved frame 552
# Saved frame 564
# Saved frame 576
# Saved frame 588
# Saved frame 600
# Saved frame 612
# Saved frame 624
# Saved frame 636
# Saved frame 648
# Saved frame 660
# Saved frame 672
# Saved frame 684
# Saved frame 696
# Saved frame 708
# Saved frame 720
# Saved frame 732
# Saved frame 744
# Saved frame 756
# Saved frame 768
# Saved frame 780
# Saved frame 792
# Saved frame 804
# Saved frame 816
# Saved frame 828
# Saved frame 840
# Saved frame 852
# Saved frame 864
# Saved frame 876
# Saved frame 888
# Saved frame 900
# Saved frame 912
# Saved frame 924
# Saved frame 936
# Saved frame 948
# Saved frame 960
# Saved frame 972
# Saved frame 984
# Saved frame 996
# Saved frame 1008
# Saved frame 1020
# Saved frame 1032
# Saved frame 1044
# Saved frame 1056
# Saved frame 1068
# Saved frame 1080
# Saved frame 1092
# Saved frame 1104
# Saved frame 1116
# Saved frame 1128
# Saved frame 1140
# Saved frame 1152
# Saved frame 1164
# Saved frame 1176
# Saved frame 1188
# Saved frame 1200
# Saved frame 1212
# Saved frame 1224
# Saved frame 1236
# Saved frame 1248
# Saved frame 1260
# Saved frame 1272
# Saved frame 1284
# Saved frame 1296
# Saved frame 1308
# Saved frame 1320
# Saved frame 1332
# Saved frame 1344
# Saved frame 1356
# Saved frame 1368
# Saved frame 1380
# Saved frame 1392
# Saved frame 1404
# Saved frame 1416
# Saved frame 1428
# Saved frame 1440
# Saved frame 1452
# Saved frame 1464
# Saved frame 1476
# Saved frame 1488
# Saved frame 1500
# Saved frame 1512
# Saved frame 1524
# Saved frame 1536
# Saved frame 1548
# Saved frame 1560
# Saved frame 1572
# Saved frame 1584
# Saved frame 1596
# Saved frame 1608
# Saved frame 1620
# Saved frame 1632
# Saved frame 1644
# Saved frame 1656
# Saved frame 1668
# Saved frame 1680
# Saved frame 1692
# Saved frame 1704
# Saved frame 1716
# Saved frame 1728
# Saved frame 1740
# Saved frame 1752
# Saved frame 1764
# Saved frame 1776
# Saved frame 1788
# Saved frame 1800
# Saved frame 1812
# Saved frame 1824
# Saved frame 1836
# Saved frame 1848
# Saved frame 1860
# Saved frame 1872
# Saved frame 1884
# Saved frame 1896
# Saved frame 1908
# Saved frame 1920
# Saved frame 1932
# Saved frame 1944
# Saved frame 1956
# Saved frame 1968
# Saved frame 1980
# Saved frame 1992
# Saved frame 2004
# Saved frame 2016
# Saved frame 2028
# Saved frame 2040
# Saved frame 2052
# Saved frame 2064
# Saved frame 2076
# Saved frame 2088
# Saved frame 2100
# Saved frame 2112
# Saved frame 2124
# Saved frame 2136
# Saved frame 2148
# Saved frame 2160
# Saved frame 2172
# Saved frame 2184
# Saved frame 2196
# Saved frame 2208
# Saved frame 2220
# Saved frame 2232
# Saved frame 2244
# Saved frame 2256
# Saved frame 2268
# Saved frame 2280
# Saved frame 2292
# Saved frame 2304
# Saved frame 2316
# Saved frame 2328
# Saved frame 2340
# Saved frame 2352
# Saved frame 2364
# Saved frame 2376
# Saved frame 2388
# Saved frame 2400
# Saved frame 2412
# Saved frame 2424
# Saved frame 2436
# Saved frame 2448
# Saved frame 2460
# Saved frame 2472
# Saved frame 2484
# Saved frame 2496
# Saved frame 2508
# Saved frame 2520
# Saved frame 2532
# Saved frame 2544
# Saved frame 2556
# Saved frame 2568
# Saved frame 2580
# Saved frame 2592
# Saved frame 2604
# Saved frame 2616
# Saved frame 2628
# Saved frame 2640
# Saved frame 2652
# Saved frame 2664
# Saved frame 2676
# Saved frame 2688
# Saved frame 2700
# Saved frame 2712
# Saved frame 2724
# Saved frame 2736
# Saved frame 2748
# Saved frame 2760
# Saved frame 2772
# Saved frame 2784
# Saved frame 2796
# Saved frame 2808
# Saved frame 2820
# Saved frame 2832
# Saved frame 2844
# Saved frame 2856
# Saved frame 2868
# Saved frame 2880
# Saved frame 2892
# Saved frame 2904
# Saved frame 2916
# Saved frame 2928
# Saved frame 2940
# Saved frame 2952
# Saved frame 2964
# Saved frame 2976
# Saved frame 2988
# Saved frame 3000
# Saved frame 3012
# Saved frame 3024
# Saved frame 3036
# Saved frame 3048
# Saved frame 3060
# Saved frame 3072
# Saved frame 3084
# Saved frame 3096
# Saved frame 3108
# Saved frame 3120
# Saved frame 3132
# Saved frame 3144
# Saved frame 3156
# Saved frame 3168
# Saved frame 3180
# Saved frame 3192
# Saved frame 3204
# Saved frame 3216
# Saved frame 3228
# Saved frame 3240
# Saved frame 3252
# Saved frame 3264
# Saved frame 3276
# Saved frame 3288
# Saved frame 3300
# Saved frame 3312
# Saved frame 3324
# Saved frame 3336
# Saved frame 3348
# Saved frame 3360
# Saved frame 3372
# Saved frame 3384
# Saved frame 3396
# Saved frame 3408
# Saved frame 3420
# Saved frame 3432
# Saved frame 3444
# Saved frame 3456
# Saved frame 3468
# Saved frame 3480
# Saved frame 3492
# Saved frame 3504
# Saved frame 3516
# Saved frame 3528
# Saved frame 3540
# Saved frame 3552
# Saved frame 3564
# Saved frame 3576
# Saved frame 3588
# Saved frame 3600
# Saved frame 3612
# Saved frame 3624
# Saved frame 3636
# Saved frame 3648
# Saved frame 3660
# Saved frame 3672
# Saved frame 3684
# Saved frame 3696
# Saved frame 3708
# Saved frame 3720
# Saved frame 3732
# Saved frame 3744
# Saved frame 3756
# Saved frame 3768
# Saved frame 3780
# Saved frame 3792
# Saved frame 3804
# Saved frame 3816
# Saved frame 3828
# Saved frame 3840
# Saved frame 3852
# Saved frame 3864
# Saved frame 3876
# Saved frame 3888
# Saved frame 3900
# Saved frame 3912
# Saved frame 3924
# Saved frame 3936
# Saved frame 3948
# Saved frame 3960
# Saved frame 3972
# Saved frame 3984
# Saved frame 3996
# Saved frame 4008
# Saved frame 4020
# Saved frame 4032
# Saved frame 4044
# Saved frame 4056
# Saved frame 4068
# Saved frame 4080
# Saved frame 4092
# Saved frame 4104
# Saved frame 4116
# Saved frame 4128
# Saved frame 4140
# Saved frame 4152
# Saved frame 4164
# Saved frame 4176
# Saved frame 4188
# Saved frame 4200
# Saved frame 4212
# Saved frame 4224
# Saved frame 4236
# Saved frame 4248
# Saved frame 4260
# Saved frame 4272
# Saved frame 4284
# Saved frame 4296
# Saved frame 4308
# Saved frame 4320
# Saved frame 4332
# Saved frame 4344
# Saved frame 4356
# Saved frame 4368
# Saved frame 4380
# Saved frame 4392
# Saved frame 4404
# Saved frame 4416
# Saved frame 4428
# Saved frame 4440
# Saved frame 4452
# Saved frame 4464
# Saved frame 4476
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97002997002997
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# Saved frame 480
# Saved frame 540
# Saved frame 600
# Saved frame 660
# Saved frame 720
# Saved frame 780
# Saved frame 840
# Saved frame 900
# Saved frame 960
# Saved frame 1020
# Saved frame 1080
# Saved frame 1140
# Saved frame 1200
# Saved frame 1260
# Saved frame 1320
# Saved frame 1380
# Saved frame 1440
# Saved frame 1500
# Saved frame 1560
# Saved frame 1620
# Saved frame 1680
# Saved frame 1740
# Saved frame 1800
# Saved frame 1860
# Saved frame 1920
# Saved frame 1980
# Saved frame 2040
# Saved frame 2100
# Saved frame 2160
# Saved frame 2220
# Saved frame 2280
# Saved frame 2340
# Saved frame 2400
# Saved frame 2460
# Saved frame 2520
# Saved frame 2580
# Saved frame 2640
# Saved frame 2700
# Saved frame 2760
# Saved frame 2820
# Saved frame 2880
# Saved frame 2940
# Saved frame 3000
# Saved frame 3060
# Saved frame 3120
# Saved frame 3180
# Saved frame 3240
# Saved frame 3300
# Saved frame 3360
# Saved frame 3420
# Saved frame 3480
# Saved frame 3540
# Saved frame 3600
# Saved frame 3660
# Saved frame 3720
# Saved frame 3780
# Saved frame 3840
# Saved frame 3900
# Saved frame 3960
# Saved frame 4020
# Saved frame 4080
# Saved frame 4140
# Saved frame 4200
# Saved frame 4260
# Saved frame 4320
# Saved frame 4380
# Saved frame 4440
# Saved frame 4500
# Saved frame 4560
# Saved frame 4620
# Saved frame 4680
# Saved frame 4740
# Saved frame 4800
# Saved frame 4860
# Saved frame 4920
# Saved frame 4980
# Saved frame 5040
# Saved frame 5100
# Saved frame 5160
# Saved frame 5220
# Saved frame 5280
# Saved frame 5340
# Saved frame 5400
# Saved frame 5460
# Saved frame 5520
# Saved frame 5580
# Saved frame 5640
# Saved frame 5700
# Saved frame 5760
# Saved frame 5820
# Saved frame 5880
# Saved frame 5940
# Saved frame 6000
# Saved frame 6060
# Saved frame 6120
# Saved frame 6180
# Saved frame 6240
# Saved frame 6300
# Saved frame 6360
# Saved frame 6420
# Saved frame 6480
# Saved frame 6540
# Saved frame 6600
# Saved frame 6660
# Saved frame 6720
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97002997002997
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# Saved frame 450
# Saved frame 480
# Saved frame 510
# Saved frame 540
# Saved frame 570
# Saved frame 600
# Saved frame 630
# Saved frame 660
# Saved frame 690
# Saved frame 720
# Saved frame 750
# Saved frame 780
# Saved frame 810
# Saved frame 840
# Saved frame 870
# Saved frame 900
# Saved frame 930
# Saved frame 960
# Saved frame 990
# Saved frame 1020
# Saved frame 1050
# Saved frame 1080
# Saved frame 1110
# Saved frame 1140
# Saved frame 1170
# Saved frame 1200
# Saved frame 1230
# Saved frame 1260
# Saved frame 1290
# Saved frame 1320
# Saved frame 1350
# Saved frame 1380
# Saved frame 1410
# Saved frame 1440
# Saved frame 1470
# Saved frame 1500
# Saved frame 1530
# Saved frame 1560
# Saved frame 1590
# Saved frame 1620
# Saved frame 1650
# Saved frame 1680
# Saved frame 1710
# Saved frame 1740
# Saved frame 1770
# Saved frame 1800
# Saved frame 1830
# Saved frame 1860
# Saved frame 1890
# Saved frame 1920
# Saved frame 1950
# Saved frame 1980
# Saved frame 2010
# Saved frame 2040
# Saved frame 2070
# Saved frame 2100
# Saved frame 2130
# Saved frame 2160
# Saved frame 2190
# Saved frame 2220
# Saved frame 2250
# Saved frame 2280
# Saved frame 2310
# Saved frame 2340
# Saved frame 2370
# Saved frame 2400
# Saved frame 2430
# Saved frame 2460
# Saved frame 2490
# Saved frame 2520
# Saved frame 2550
# Saved frame 2580
# Saved frame 2610
# Saved frame 2640
# Saved frame 2670
# Saved frame 2700
# Saved frame 2730
# Saved frame 2760
# Saved frame 2790
# Saved frame 2820
# Saved frame 2850
# Saved frame 2880
# Saved frame 2910
# Saved frame 2940
# Saved frame 2970
# Saved frame 3000
# Saved frame 3030
# Saved frame 3060
# Saved frame 3090
# Saved frame 3120
# Saved frame 3150
# Saved frame 3180
# Saved frame 3210
# Saved frame 3240
# Saved frame 3270
# Saved frame 3300
# Saved frame 3330
# Saved frame 3360
# Saved frame 3390
# Saved frame 3420
# Saved frame 3450
# Saved frame 3480
# Saved frame 3510
# Saved frame 3540
# Saved frame 3570
# Saved frame 3600
# Saved frame 3630
# Saved frame 3660
# Saved frame 3690
# Saved frame 3720
# Saved frame 3750
# Saved frame 3780
# Saved frame 3810
# Saved frame 3840
# Saved frame 3870
# Saved frame 3900
# Saved frame 3930
# Saved frame 3960
# Saved frame 3990
# Saved frame 4020
# Saved frame 4050
# Saved frame 4080
# Saved frame 4110
# Saved frame 4140
# Saved frame 4170
# Saved frame 4200
# Saved frame 4230
# Saved frame 4260
# Saved frame 4290
# Saved frame 4320
# Saved frame 4350
# Saved frame 4380
# Saved frame 4410
# Saved frame 4440
# Saved frame 4470
# Saved frame 4500
# Saved frame 4530
# Saved frame 4560
# Saved frame 4590
# Saved frame 4620
# Saved frame 4650
# Saved frame 4680
# Saved frame 4710
# Saved frame 4740
# Saved frame 4770
# Saved frame 4800
# Saved frame 4830
# Saved frame 4860
# Saved frame 4890
# Saved frame 4920
# Saved frame 4950
# Saved frame 4980
# Saved frame 5010
# Saved frame 5040
# Saved frame 5070
# Saved frame 5100
# Saved frame 5130
# Saved frame 5160
# Saved frame 5190
# Saved frame 5220
# Saved frame 5250
# Saved frame 5280
# Saved frame 5310
# Saved frame 5340
# Saved frame 5370
# Saved frame 5400
# Saved frame 5430
# Saved frame 5460
# Saved frame 5490
# Saved frame 5520
# Saved frame 5550
# Saved frame 5580
# Saved frame 5610
# Saved frame 5640
# Saved frame 5670
# Saved frame 5700
# Saved frame 5730
# Saved frame 5760
# Saved frame 5790
# Saved frame 5820
# Saved frame 5850
# Saved frame 5880
# Saved frame 5910
# Saved frame 5940
# Saved frame 5970
# Saved frame 6000
# Saved frame 6030
# Saved frame 6060
# Saved frame 6090
# Saved frame 6120
# Saved frame 6150
# Saved frame 6180
# Saved frame 6210
# Saved frame 6240
# Saved frame 6270
# Saved frame 6300
# Saved frame 6330
# Saved frame 6360
# Saved frame 6390
# Saved frame 6420
# Saved frame 6450
# Saved frame 6480
# Saved frame 6510
# Saved frame 6540
# Saved frame 6570
# Saved frame 6600
# Saved frame 6630
# Saved frame 6660
# Saved frame 6690
# Saved frame 6720
# Saved frame 6750
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97002997002997
# Saved frame 0
# Saved frame 15
# Saved frame 30
# Saved frame 45
# Saved frame 60
# Saved frame 75
# Saved frame 90
# Saved frame 105
# Saved frame 120
# Saved frame 135
# Saved frame 150
# Saved frame 165
# Saved frame 180
# Saved frame 195
# Saved frame 210
# Saved frame 225
# Saved frame 240
# Saved frame 255
# Saved frame 270
# Saved frame 285
# Saved frame 300
# Saved frame 315
# Saved frame 330
# Saved frame 345
# Saved frame 360
# Saved frame 375
# Saved frame 390
# Saved frame 405
# Saved frame 420
# Saved frame 435
# Saved frame 450
# Saved frame 465
# Saved frame 480
# Saved frame 495
# Saved frame 510
# Saved frame 525
# Saved frame 540
# Saved frame 555
# Saved frame 570
# Saved frame 585
# Saved frame 600
# Saved frame 615
# Saved frame 630
# Saved frame 645
# Saved frame 660
# Saved frame 675
# Saved frame 690
# Saved frame 705
# Saved frame 720
# Saved frame 735
# Saved frame 750
# Saved frame 765
# Saved frame 780
# Saved frame 795
# Saved frame 810
# Saved frame 825
# Saved frame 840
# Saved frame 855
# Saved frame 870
# Saved frame 885
# Saved frame 900
# Saved frame 915
# Saved frame 930
# Saved frame 945
# Saved frame 960
# Saved frame 975
# Saved frame 990
# Saved frame 1005
# Saved frame 1020
# Saved frame 1035
# Saved frame 1050
# ...
# Saved frame 2220
# Saved frame 2226
# Saved frame 2232
# Saved frame 2238
# Saved frame 2244
# Saved frame 2250
# Saved frame 2256
# Saved frame 2262
# Saved frame 2268
# Saved frame 2274
# Saved frame 2280
# Saved frame 2286
# Saved frame 2292
# Saved frame 2298
# Saved frame 2304
# Saved frame 2310
# Saved frame 2316
# Saved frame 2322
# Saved frame 2328
# Saved frame 2334
# Saved frame 2340
# Saved frame 2346
# Saved frame 2352
# Saved frame 2358
# Saved frame 2364
# Saved frame 2370
# Saved frame 2376
# Saved frame 2382
# Saved frame 2388
# Saved frame 2394
# Saved frame 2400
# Saved frame 2406
# Saved frame 2412
# Saved frame 2418
# Saved frame 2424
# Saved frame 2430
# Saved frame 2436
# Saved frame 2442
# Saved frame 2448
# Saved frame 2454
# Saved frame 2460
# Saved frame 2466
# Saved frame 2472
# Saved frame 2478
# Saved frame 2484
# Saved frame 2490
# Saved frame 2496
# Saved frame 2502
# Saved frame 2508
# Saved frame 2514
# Saved frame 2520
# Saved frame 2526
# Saved frame 2532
# Saved frame 2538
# Saved frame 2544
# Saved frame 2550
# Saved frame 2556
# Saved frame 2562
# Saved frame 2568
# Saved frame 2574
# Saved frame 2580
# Saved frame 2586
# Saved frame 2592
# Saved frame 2598
# Saved frame 2604
# Saved frame 2610
# Saved frame 2616
# Saved frame 2622
# Saved frame 2628
# Saved frame 2634
# Saved frame 2640
# Saved frame 2646
# Saved frame 2652
# Saved frame 2658
# Saved frame 2664
# Saved frame 2670
# Saved frame 2676
# Saved frame 2682
# Saved frame 2688
# Saved frame 2694
# Saved frame 2700
# Saved frame 2706
# Saved frame 2712
# Saved frame 2718
# Saved frame 2724
# Saved frame 2730
# Saved frame 2736
# Saved frame 2742
# Saved frame 2748
# Saved frame 2754
# Saved frame 2760
# Saved frame 2766
# Saved frame 2772
# Saved frame 2778
# Saved frame 2784
# Saved frame 2790
# Saved frame 2796
# Saved frame 2802
# Saved frame 2808
# Saved frame 2814
# Saved frame 2820
# Saved frame 2826
# Saved frame 2832
# Saved frame 2838
# Saved frame 2844
# Saved frame 2850
# Saved frame 2856
# Saved frame 2862
# Saved frame 2868
# Saved frame 2874
# Saved frame 2880
# Saved frame 2886
# Saved frame 2892
# Saved frame 2898
# Saved frame 2904
# Saved frame 2910
# Saved frame 2916
# Saved frame 2922
# Saved frame 2928
# Saved frame 2934
# Saved frame 2940
# Saved frame 2946
# Saved frame 2952
# Saved frame 2958
# Saved frame 2964
# Saved frame 2970
# Saved frame 2976
# Saved frame 2982
# Saved frame 2988
# Saved frame 2994
# Saved frame 3000
# Saved frame 3006
# Saved frame 3012
# Saved frame 3018
# Saved frame 3024
# Saved frame 3030
# Saved frame 3036
# Saved frame 3042
# Saved frame 3048
# Saved frame 3054
# Saved frame 3060
# Saved frame 3066
# Saved frame 3072
# Saved frame 3078
# Saved frame 3084
# Saved frame 3090
# Saved frame 3096
# Saved frame 3102
# Saved frame 3108
# Saved frame 3114
# Saved frame 3120
# Saved frame 3126
# Saved frame 3132
# Saved frame 3138
# Saved frame 3144
# Saved frame 3150
# Saved frame 3156
# Saved frame 3162
# Saved frame 3168
# Saved frame 3174
# Saved frame 3180
# Saved frame 3186
# Saved frame 3192
# Saved frame 3198
# Saved frame 3204
# Saved frame 3210
# Saved frame 3216
# Saved frame 3222
# Saved frame 3228
# Saved frame 3234
# Saved frame 3240
# Saved frame 3246
# Saved frame 3252
# Saved frame 3258
# Saved frame 3264
# Saved frame 3270
# Saved frame 3276
# Saved frame 3282
# Saved frame 3288
# Saved frame 3294
# Saved frame 3300
# Saved frame 3306
# Saved frame 3312
# Saved frame 3318
# Saved frame 3324
# Saved frame 3330
# Saved frame 3336
# Saved frame 3342
# Saved frame 3348
# Saved frame 3354
# Saved frame 3360
# Saved frame 3366
# Saved frame 3372
# Saved frame 3378
# Saved frame 3384
# Saved frame 3390
# Saved frame 3396
# Saved frame 3402
# Saved frame 3408
# Saved frame 3414
# Saved frame 3420
# Saved frame 3426
# Saved frame 3432
# Saved frame 3438
# Saved frame 3444
# Saved frame 3450
# Saved frame 3456
# Saved frame 3462
# Saved frame 3468
# Saved frame 3474
# Saved frame 3480
# Saved frame 3486
# Saved frame 3492
# Saved frame 3498
# Saved frame 3504
# Saved frame 3510
# Saved frame 3516
# Saved frame 3522
# Saved frame 3528
# Saved frame 3534
# Saved frame 3540
# Saved frame 3546
# Saved frame 3552
# Saved frame 3558
# Saved frame 3564
# Saved frame 3570
# Saved frame 3576
# Saved frame 3582
# Saved frame 3588
# Saved frame 3594
# Saved frame 3600
# Saved frame 3606
# Saved frame 3612
# Saved frame 3618
# Saved frame 3624
# Saved frame 3630
# Saved frame 3636
# Saved frame 3642
# Saved frame 3648
# Saved frame 3654
# Saved frame 3660
# Saved frame 3666
# Saved frame 3672
# Saved frame 3678
# Saved frame 3684
# Saved frame 3690
# Saved frame 3696
# Saved frame 3702
# Saved frame 3708
# Saved frame 3714
# Saved frame 3720
# Saved frame 3726
# Saved frame 3732
# Saved frame 3738
# Saved frame 3744
# Saved frame 3750
# Saved frame 3756
# Saved frame 3762
# Saved frame 3768
# Saved frame 3774
# Saved frame 3780
# Saved frame 3786
# Saved frame 3792
# Saved frame 3798
# Saved frame 3804
# Saved frame 3810
# Saved frame 3816
# Saved frame 3822
# Saved frame 3828
# Saved frame 3834
# Saved frame 3840
# Saved frame 3846
# Saved frame 3852
# Saved frame 3858
# Saved frame 3864
# Saved frame 3870
# Saved frame 3876
# Saved frame 3882
# Saved frame 3888
# Saved frame 3894
# Saved frame 3900
# Saved frame 3906
# Saved frame 3912
# Saved frame 3918
# Saved frame 3924
# Saved frame 3930
# Saved frame 3936
# Saved frame 3942
# Saved frame 3948
# Saved frame 3954
# Saved frame 3960
# Saved frame 3966
# Saved frame 3972
# Saved frame 3978
# Saved frame 3984
# Saved frame 3990
# Saved frame 3996
# Saved frame 4002
# Saved frame 4008
# Saved frame 4014
# Saved frame 4020
# Saved frame 4026
# Saved frame 4032
# Saved frame 4038
# Saved frame 4044
# Saved frame 4050
# Saved frame 4056
# Saved frame 4062
# Saved frame 4068
# Saved frame 4074
# Saved frame 4080
# Saved frame 4086
# Saved frame 4092
# Saved frame 4098
# Saved frame 4104
# Saved frame 4110
# Saved frame 4116
# Saved frame 4122
# Saved frame 4128
# Saved frame 4134
# Saved frame 4140
# Saved frame 4146
# Saved frame 4152
# Saved frame 4158
# Saved frame 4164
# Saved frame 4170
# Saved frame 4176
# Saved frame 4182
# Saved frame 4188
# Saved frame 4194
# Saved frame 4200
# Saved frame 4206
# Saved frame 4212
# Saved frame 4218
# Saved frame 4224
# Saved frame 4230
# Saved frame 4236
# Saved frame 4242
# Saved frame 4248
# Saved frame 4254
# Saved frame 4260
# Saved frame 4266
# Saved frame 4272
# Saved frame 4278
# Saved frame 4284
# Saved frame 4290
# Saved frame 4296
# Saved frame 4302
# Saved frame 4308
# Saved frame 4314
# Saved frame 4320
# Saved frame 4326
# Saved frame 4332
# Saved frame 4338
# Saved frame 4344
# Saved frame 4350
# Saved frame 4356
# Saved frame 4362
# Saved frame 4368
# Saved frame 4374
# Saved frame 4380
# Saved frame 4386
# Saved frame 4392
# Saved frame 4398
# Saved frame 4404
# Saved frame 4410
# Saved frame 4416
# Saved frame 4422
# Saved frame 4428
# Saved frame 4434
# Saved frame 4440
# Saved frame 4446
# Saved frame 4452
# Saved frame 4458
# Saved frame 4464
# Saved frame 4470
# Saved frame 4476
# Saved frame 4482
# Saved frame 4488
# Saved frame 4494
# Saved frame 4500
# Saved frame 4506
# Saved frame 4512
# Saved frame 4518
# Saved frame 4524
# Saved frame 4530
# Saved frame 4536
# Saved frame 4542
# Saved frame 4548
# Saved frame 4554
# Saved frame 4560
# Saved frame 4566
# Saved frame 4572
# Saved frame 4578
# Saved frame 4584
# Saved frame 4590
# Saved frame 4596
# Saved frame 4602
# Saved frame 4608
# Saved frame 4614
# Saved frame 4620
# Saved frame 4626
# Saved frame 4632
# Saved frame 4638
# Saved frame 4644
# Saved frame 4650
# Saved frame 4656
# Saved frame 4662
# Saved frame 4668
# Saved frame 4674
# Saved frame 4680
# Saved frame 4686
# Saved frame 4692
# Saved frame 4698
# Saved frame 4704
# Saved frame 4710
# Saved frame 4716
# Saved frame 4722
# Saved frame 4728
# Saved frame 4734
# Saved frame 4740
# Saved frame 4746
# Saved frame 4752
# Saved frame 4758
# Saved frame 4764
# Saved frame 4770
# Saved frame 4776
# Saved frame 4782
# Saved frame 4788
# Saved frame 4794
# Saved frame 4800
# Saved frame 4806
# Saved frame 4812
# Saved frame 4818
# Saved frame 4824
# Saved frame 4830
# Saved frame 4836
# Saved frame 4842
# Saved frame 4848
# Saved frame 4854
# Saved frame 4860
# Saved frame 4866
# Saved frame 4872
# Saved frame 4878
# Saved frame 4884
# Saved frame 4890
# Saved frame 4896
# Saved frame 4902
# Saved frame 4908
# Saved frame 4914
# Saved frame 4920
# Saved frame 4926
# Saved frame 4932
# Saved frame 4938
# Saved frame 4944
# Saved frame 4950
# Saved frame 4956
# Saved frame 4962
# Saved frame 4968
# Saved frame 4974
# Saved frame 4980
# Saved frame 4986
# Saved frame 4992
# Saved frame 4998
# Saved frame 5004
# Saved frame 5010
# Saved frame 5016
# Saved frame 5022
# Saved frame 5028
# Saved frame 5034
# Saved frame 5040
# Saved frame 5046
# Saved frame 5052
# Saved frame 5058
# Saved frame 5064
# Saved frame 5070
# Saved frame 5076
# Saved frame 5082
# Saved frame 5088
# Saved frame 5094
# Saved frame 5100
# Saved frame 5106
# Saved frame 5112
# Saved frame 5118
# Saved frame 5124
# Saved frame 5130
# Saved frame 5136
# Saved frame 5142
# Saved frame 5148
# Saved frame 5154
# Saved frame 5160
# Saved frame 5166
# Saved frame 5172
# Saved frame 5178
# Saved frame 5184
# Saved frame 5190
# Saved frame 5196
# Saved frame 5202
# Saved frame 5208
# Saved frame 5214
# Saved frame 5220
# Saved frame 5226
# Saved frame 5232
# Saved frame 5238
# Saved frame 5244
# Saved frame 5250
# Saved frame 5256
# Saved frame 5262
# Saved frame 5268
# Saved frame 5274
# Saved frame 5280
# Saved frame 5286
# Saved frame 5292
# Saved frame 5298
# Saved frame 5304
# Saved frame 5310
# Saved frame 5316
# Saved frame 5322
# Saved frame 5328
# Saved frame 5334
# Saved frame 5340
# Saved frame 5346
# Saved frame 5352
# Saved frame 5358
# Saved frame 5364
# Saved frame 5370
# Saved frame 5376
# Saved frame 5382
# Saved frame 5388
# Saved frame 5394
# Saved frame 5400
# Saved frame 5406
# Saved frame 5412
# Saved frame 5418
# Saved frame 5424
# Saved frame 5430
# Saved frame 5436
# Saved frame 5442
# Saved frame 5448
# Saved frame 5454
# Saved frame 5460
# Saved frame 5466
# Saved frame 5472
# Saved frame 5478
# Saved frame 5484
# Saved frame 5490
# Saved frame 5496
# Saved frame 5502
# Saved frame 5508
# Saved frame 5514
# Saved frame 5520
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 15
# Saved frame 30
# Saved frame 45
# Saved frame 60
# Saved frame 75
# Saved frame 90
# Saved frame 105
# Saved frame 120
# Saved frame 135
# Saved frame 150
# Saved frame 165
# Saved frame 180
# Saved frame 195
# Saved frame 210
# Saved frame 225
# Saved frame 240
# Saved frame 255
# Saved frame 270
# Saved frame 285
# Saved frame 300
# Saved frame 315
# Saved frame 330
# Saved frame 345
# Saved frame 360
# Saved frame 375
# Saved frame 390
# Saved frame 405
# Saved frame 420
# extracting at 5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/gfp/videos
# 29.97
# Saved frame 0
# Saved frame 6
# Saved frame 12
# Saved frame 18
# Saved frame 24
# Saved frame 30
# Saved frame 36
# Saved frame 42
# Saved frame 48
# Saved frame 54
# Saved frame 60
# Saved frame 66
# Saved frame 72
# Saved frame 78
# Saved frame 84
# Saved frame 90
# Saved frame 96
# Saved frame 102
# Saved frame 108
# Saved frame 114
# Saved frame 120
# Saved frame 126
# Saved frame 132
# Saved frame 138
# Saved frame 144
# Saved frame 150
# Saved frame 156
# Saved frame 162
# Saved frame 168
# Saved frame 174
# Saved frame 180
# Saved frame 186
# Saved frame 192
# Saved frame 198
# Saved frame 204
# Saved frame 210
# Saved frame 216
# Saved frame 222
# Saved frame 228
# Saved frame 234
# Saved frame 240
# Saved frame 246
# Saved frame 252
# Saved frame 258
# Saved frame 264
# Saved frame 270
# Saved frame 276
# Saved frame 282
# Saved frame 288
# Saved frame 294
# Saved frame 300
# Saved frame 306
# Saved frame 312
# Saved frame 318
# Saved frame 324
# Saved frame 330
# Saved frame 336
# Saved frame 342
# Saved frame 348
# Saved frame 354
# Saved frame 360
# Saved frame 366
# Saved frame 372
# Saved frame 378
# Saved frame 384
# Saved frame 390
# Saved frame 396
# Saved frame 402
# Saved frame 408
# Saved frame 414
# Saved frame 420
# extracting at 0.5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 29.97003033075395
# Saved frame 0
# Saved frame 60
# Saved frame 120
# Saved frame 180
# Saved frame 240
# Saved frame 300
# Saved frame 360
# Saved frame 420
# Saved frame 480
# Saved frame 540
# Saved frame 600
# Saved frame 660
# Saved frame 720
# Saved frame 780
# extracting at 1 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 29.97003033075395
# Saved frame 0
# Saved frame 30
# Saved frame 60
# Saved frame 90
# Saved frame 120
# Saved frame 150
# Saved frame 180
# Saved frame 210
# Saved frame 240
# Saved frame 270
# Saved frame 300
# Saved frame 330
# Saved frame 360
# Saved frame 390
# Saved frame 420
# Saved frame 450
# Saved frame 480
# Saved frame 510
# Saved frame 540
# Saved frame 570
# Saved frame 600
# Saved frame 630
# Saved frame 660
# Saved frame 690
# Saved frame 720
# Saved frame 750
# Saved frame 780
# Saved frame 810
# extracting at 2 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 29.97003033075395
# Saved frame 0
# Saved frame 15
# Saved frame 30
# Saved frame 45
# Saved frame 60
# Saved frame 75
# Saved frame 90
# Saved frame 105
# Saved frame 120
# Saved frame 135
# Saved frame 150
# Saved frame 165
# Saved frame 180
# Saved frame 195
# Saved frame 210
# Saved frame 225
# Saved frame 240
# Saved frame 255
# Saved frame 270
# Saved frame 285
# Saved frame 300
# Saved frame 315
# Saved frame 330
# Saved frame 345
# Saved frame 360
# Saved frame 375
# Saved frame 390
# Saved frame 405
# Saved frame 420
# Saved frame 435
# Saved frame 450
# Saved frame 465
# Saved frame 480
# Saved frame 495
# Saved frame 510
# Saved frame 525
# Saved frame 540
# Saved frame 555
# Saved frame 570
# Saved frame 585
# Saved frame 600
# Saved frame 615
# Saved frame 630
# Saved frame 645
# Saved frame 660
# Saved frame 675
# Saved frame 690
# Saved frame 705
# Saved frame 720
# Saved frame 735
# Saved frame 750
# Saved frame 765
# Saved frame 780
# Saved frame 795
# Saved frame 810
# Saved frame 825
# extracting at 5 fps
# /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/frame_extraction_raw/shlife/videos
# 29.97003033075395
# Saved frame 0
# Saved frame 6
# Saved frame 12
# Saved frame 18
# Saved frame 24
# Saved frame 30
# Saved frame 36
# Saved frame 42
# Saved frame 48
# Saved frame 54
# Saved frame 60
# Saved frame 66
# Saved frame 72
# Saved frame 78
# Saved frame 84
# Saved frame 90
# Saved frame 96
# Saved frame 102
# Saved frame 108
# Saved frame 114
# Saved frame 120
# Saved frame 126
# Saved frame 132
# Saved frame 138
# Saved frame 144
# Saved frame 150
# Saved frame 156
# Saved frame 162
# Saved frame 168
# Saved frame 174
# Saved frame 180
# Saved frame 186
# Saved frame 192
# Saved frame 198
# Saved frame 204
# Saved frame 210
# Saved frame 216
# Saved frame 222
# Saved frame 228
# Saved frame 234
# Saved frame 240
# Saved frame 246
# Saved frame 252
# Saved frame 258
# Saved frame 264
# Saved frame 270
# Saved frame 276
# Saved frame 282
# Saved frame 288
# Saved frame 294
# Saved frame 300
# Saved frame 306
# Saved frame 312
# Saved frame 318
# Saved frame 324
# Saved frame 330
# Saved frame 336
# Saved frame 342
# Saved frame 348
# Saved frame 354
# Saved frame 360
# Saved frame 366
# Saved frame 372
# Saved frame 378
# Saved frame 384
# Saved frame 390
# Saved frame 396
# Saved frame 402
# Saved frame 408
# Saved frame 414
# Saved frame 420
# Saved frame 426
# Saved frame 432
# Saved frame 438
# Saved frame 444
# Saved frame 450
# Saved frame 456
# Saved frame 462
# Saved frame 468
# Saved frame 474
# Saved frame 480
# Saved frame 486
# Saved frame 492
# Saved frame 498
# Saved frame 504
# Saved frame 510
# Saved frame 516
# Saved frame 522
# Saved frame 528
# Saved frame 534
# Saved frame 540
# Saved frame 546
# Saved frame 552
# Saved frame 558
# Saved frame 564
# Saved frame 570
# Saved frame 576
# Saved frame 582
# Saved frame 588
# Saved frame 594
# Saved frame 600
# Saved frame 606
# Saved frame 612
# Saved frame 618
# Saved frame 624
# Saved frame 630
# Saved frame 636
# Saved frame 642
# Saved frame 648
# Saved frame 654
# Saved frame 660
# Saved frame 666
# Saved frame 672
# Saved frame 678
# Saved frame 684
# Saved frame 690
# Saved frame 696
# Saved frame 702
# Saved frame 708
# Saved frame 714
# Saved frame 720
# Saved frame 726
# Saved frame 732
# Saved frame 738
# Saved frame 744
# Saved frame 750
# Saved frame 756
# Saved frame 762
# Saved frame 768
# Saved frame 774
# Saved frame 780
# Saved frame 786
# Saved frame 792
# Saved frame 798
# Saved frame 804
# Saved frame 810
# Saved frame 816
# Saved frame 822
# Saved frame 828
