# %%
import cv2
import os
import shutil

# %%
# Extracting frames by frame count is inaccurate as you lose information when the video is not a multiple of desired_fps
# extract by time
def extract_fps(video_path, frame_directory, sequence, desired_fps, max_frames=1000):
    # output_path = os.path.join(frame_directory, sequence)
    # os.makedirs(output_path, exist_ok=True)
    output_path = frame_directory

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error opening video file")

    # Desired interval in seconds
    interval = 1 / desired_fps
    next_capture_time = 0.0

    count = 0  # Count of frames saved

    while cap.isOpened() and count < max_frames:
        # Get the current position of the video in seconds
        current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0
        
        # Capture frame-by-frame
        ret, frame = cap.read()
        
        # If frame is read correctly, ret is True
        if not ret:
            break
        
        # Check if the current time has reached or passed the next capture time
        if current_time >= next_capture_time:
            # Construct filename and save frame
            filename =  os.path.join(output_path, f"{sequence}_frame{count}.jpg")
            cv2.imwrite(filename, frame)
            count += 1
            # Update the next capture time
            next_capture_time += interval
        
    print(f"Extracted {count} frames from {video_path}")

    # When everything done, release the capture
    cap.release()
    print("Done extracting frames.")

# %%
output_path = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/phase3_dev/mwitt'
video_base_dir = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams'

for video in os.listdir(video_base_dir):
  for chapter in os.listdir(os.path.join(video_base_dir, video)):
    if chapter.startswith('LGX01'):
      chapter_path = os.path.join(video_base_dir, video, chapter)
      sequence = f'mwitt_{video.split("-")[1]}'
      extract_fps(chapter_path, output_path, sequence, 0.125, max_frames=5)
# Out:
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1900711/LGX012597.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1810611/LGX010118.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1860611/LGX010119.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1970711/LGX010088.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1880611/LGX010021.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1990711/LGX010024.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2070711/LGX012600.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2000711/LGX012599.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1980711/LGX010023.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2121011/LGX010135.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1870611/LGX012596.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1910711/LGX010120.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1800611/LGX012595.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2010711/LGX010122.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2060711/LGX010123.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2080711/LGX010025.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1890711/LGX010022.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2050711/LGX010134.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2020711/LGX010133.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2091011/LGX010026.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2111011/LGX010124.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1920711/LGX010131.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1830611/LGX010030.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1840611/LGX010031.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1950711/LGX010070.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2030711/LGX010034.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1790611/LGX010020.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2040711/LGX010035.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1850611/LGX010130.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1940711/LGX010033.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1930711/LGX010032.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-1820611/LGX010129.mp4
# Done extracting frames.
# Extracted 5 frames from /vol/biomedic3/bglocker/ugproj2324/fv220/datasets/videos_raw/mwitt/AXA_NOV23_no_streams/AXA_2023-2101011/LGX012602.mp4
# Done extracting frames.
