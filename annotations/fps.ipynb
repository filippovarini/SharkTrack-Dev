# %% [markdown]
# ## Standard format 10fps to 1fps

# %%
import pandas as pd
import os


annotations_10fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/val2/annotations_10fps/annotations_standard/'
annotations_1fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/val2/annotations_1fps/annotations_standard/'

for filename in os.listdir(annotations_10fps):
  if filename.endswith('.csv'):
    print(f'Processing {filename}')
    # read the 10fps annotations dataframe and extract only the rows where the filename ends with a multiple of ten. Note that every filename value has the following format: '<video_name>_frame<number>.jpg' example: "difficult1_frame4495.jpg"
    df = pd.read_csv(annotations_10fps + filename)
    df_out = df[df['Filename'].str.contains('frame[0-9]*0.jpg')]
    # save the filtered dataframe to a new csv file
    print(f'10fps row count = {len(df)}, 1fps row count = {len(df_out)}')
    df_out.to_csv(annotations_1fps + filename, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 annotations_10fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/val2/annotations_10fps/annotations_viame/'
#       6 annotations_1fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/val2/annotations_1fps/annotations_viame/'
# ----> 8 for filename in os.listdir(annotations_10fps):
#       9   if filename.endswith('.csv'):
#      10     print(f'Processing {filename}')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/val2/annotations_10fps/annotations_viame/'

# %%
# For viame annotations:
annotations_10fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/annotations_10fps/annotations_viame/'
annotations_1fps = '/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/annotations_1fps/annotations_viame/'

for filename in os.listdir(annotations_10fps):
  if filename.endswith('.csv'):
    print(f'Processing {filename}')
    # read the 10fps annotations dataframe and extract only the rows where the filename ends with a multiple of ten. Note that every filename value has the following format: '<video_name>_frame<number>.jpg' example: "difficult1_frame4495.jpg"
    df = pd.read_csv(annotations_10fps + filename)
    df_out = df[df['3: Unique Frame Identifier'].astype(str).str.contains('[0-9]*0')]
    # save the filtered dataframe to a new csv file
    print(f'10fps row count = {len(df)}, 1fps row count = {len(df_out)}')
    df_out.to_csv(annotations_1fps + filename, index=False)
# Out:
# Processing easy1.csv
# 10fps row count = 304, 1fps row count = 38
# Processing medium1.csv
# 10fps row count = 282, 1fps row count = 46
# Processing difficult2.csv
# 10fps row count = 374, 1fps row count = 57
# Processing difficult1.csv
# 10fps row count = 358, 1fps row count = 60
# Processing easy2.csv
# 10fps row count = 165, 1fps row count = 26
# Processing medium2.csv
# 10fps row count = 334, 1fps row count = 60

# %%
df = pd.read_csv('/vol/biomedic3/bglocker/ugproj2324/fv220/datasets/validation/annotations_1fps/annotations_viame/easy1.csv')
df.head()
# Out:
#    # 1: Detection or Track-id 2: Video or Image Identifier  \
# 0                           1                      00:03.0
# 1                           1                      00:04.0
# 2                           1                      00:05.0
# 3                           1                      00:06.0
# 4                           1                      00:07.0
#
#    3: Unique Frame Identifier  4-7: Img-bbox(TL_x  TL_y  BR_x  BR_y)  \
# 0                          30                   0   347   133    459
# 1                          40                  -6   314   127    426
# 2                          50                   2   456   228    612
# 3                          60                  67   301   410    466
# 4                          70                 211   275   555    436
#
#    8: Detection or Length Confidence  9: Target Length (0 or -1 if invalid)  \
# 0                                  1                                     -1
# 1                                  1                                     -1
# 2                                  1                                     -1
# 3                                  1                                     -1
# 4                                  1                                     -1
#
#   10-11+: Repeated Species  Confidence Pairs or Attributes
# 0                    shark                               1
# 1                    shark                               1
# 2                    shark                               1
# 3                    shark                               1
# 4                    shark                               1
