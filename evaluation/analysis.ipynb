# %%
import pandas as pd

# %%
df = pd.read_csv('hyperparameter_tuning/5fps.csv')

# %%
# Show top 5 rows by mota
df.sort_values(by='mota', ascending=False).head(20)
# Out:
#    tracker_type  track_high_thresh  track_low_thresh  new_track_thresh  \
# 9       botsort                0.4               0.1               0.4
# 73      botsort                0.4               0.2               0.4
# 74      botsort                0.4               0.2               0.4
# 79      botsort                0.4               0.2               0.4
# 8       botsort                0.4               0.1               0.4
# 13      botsort                0.4               0.1               0.4
# 78      botsort                0.4               0.2               0.4
# 19      botsort                0.4               0.1               0.4
# 18      botsort                0.4               0.1               0.4
# 68      botsort                0.4               0.2               0.4
# 69      botsort                0.4               0.2               0.4
# 14      botsort                0.4               0.1               0.4
# ...

# %%
# Plot the track_low_thresh vs mota
plt.scatter(df['track_low_thresh'], df['mota'])
plt.xlabel('track_low_thresh')
plt.ylabel('mota')
plt.show()

# %%
# Plot the track_low_thresh vs mota
plt.scatter(df['track_high_thresh'], df['mota'])
plt.xlabel('track_low_thresh')
plt.ylabel('mota')
plt.show()

# %%
# Plot the track_low_thresh vs mota
plt.scatter(df['new_track_thresh'], df['mota'])
plt.xlabel('track_low_thresh')
plt.ylabel('mota')
plt.show()
