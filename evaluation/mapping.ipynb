# %%
chap_track_class_mapping = {
  '12': {
    1: 'algae',
  },
  '8': { # investigate
    6: 'algae',
    7: 'shark',
    9: 'shark',
    10: 'shark',
    12: 'shark',
    

  },
  '10': {
    1: 'above-water',
    4: 'above-water',
    5: 'above-water',
    6: 'above-water',
    7: 'above-water',
    14: 'algae',
    21: 'algae',
    34: 'algae',
  },
  '06': {
    16: 'algae',
    21: 'algae',
    26: 'algae',
  }
  '05': {
    1: 'algae',
    7: 'algae',
    19: 'algae',
    20: 'algae',
    29: 'algae',
  },
  '07': {
    6: 'algae',
    7: 'algae',
    8: 'algae',
    16: 'algae',
    27: 'algae',
    28: 'algae',
    40: 'algae',
    41: 'algae',
  },
  '09': {
    7: 'algae',
    15: 'algae',
    18: 'algae',
    21: 'algae',
    24: 'algae',


}
